# %% [markdown]
# # Zillow Housing Affordability Data Visualization

# %% [markdown]
# __Date__: 04/30/2019
#
# __Author__: Zexi Ye
#
# __Email__: zy1311@nyu.edu

# %% [markdown]
# ## Description
#
# This notebook contains 3 interactive time series plots on <font color='red'>Price-to-Income Ratio</font>, <font color='blue'>Mortage Affordability</font> and <font color='green'>Renter Affordability</font> over the period 1979-03 to 2018-06. You may move your cursor horizontally on the plots to view the actual values of the data at each quarter.
#
# 5 metropolitan areas as well as the United States national-level data are selected for plotting. The 5 metropolitan areas are areas that rank the maximum, 25%, median, 75% and minimum in population, respectively. Below is a detailed list:
#
# Max - <font color='green'>New York, NY</font>
#
# 25% - <font color='blue'>Augusta, GA</font>
#
# Median - <font color='orange'>Yakima, WA</font>
#
# 75% - <font color='purple'>Auburn, AL</font>
#
# Min - <font color='red'>Carson City, NV</font>

# %%
# Import packages
import numpy as np
import pandas as pd
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %% [markdown]
# ## Price-to-income Ratio Historical Data with Interaction

# %%
# Load in data
pti_long = pd.read_csv('./data_for_plot/pti_ts_data.csv')

# %%
# Create a selection that chooses the nearest point & selects based on x-value
nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['Time'], empty='none')

# The basic line
line = alt.Chart(pti_long).mark_line(interpolate='basis').encode(
    x='Time:T',
    y='Price-to-income Index:Q',
    color='Area:N'
)

# Transparent selectors across the chart. This is what tells us
# the x-value of the cursor
selectors = alt.Chart(pti_long).mark_point().encode(
    x='Time:T',
    opacity=alt.value(0),
).add_selection(
    nearest
)

# Draw points on the line, and highlight based on selection
points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

# Draw text labels near the points, and highlight based on selection
text = line.mark_text(align='left', dx=5, dy=-5).encode(
    text=alt.condition(nearest, 'Price-to-income Index:Q', alt.value(' '))
)

# Draw a rule at the location of the selection
rules = alt.Chart(pti_long).mark_rule(color='gray').encode(
    x='Time:T',
).transform_filter(
    nearest
)

# Put the five layers into a chart and bind the data
alt.layer(
    line, selectors, points, rules, text
).properties(
    width=600, height=500
)

# %% [markdown]
# ## Mortgage Affordability Historical Data with Interaction

# %%
# Load in data
ma_long = pd.read_csv('./data_for_plot/ma_ts_data.csv')

# %%
# Create a selection that chooses the nearest point & selects based on x-value
nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['Time'], empty='none')

# The basic line
line = alt.Chart(ma_long).mark_line(interpolate='basis').encode(
    x='Time:T',
    y='Mortgage Affordability:Q',
    color='Area:N'
)

# Transparent selectors across the chart. This is what tells us
# the x-value of the cursor
selectors = alt.Chart(ma_long).mark_point().encode(
    x='Time:T',
    opacity=alt.value(0),
).add_selection(
    nearest
)

# Draw points on the line, and highlight based on selection
points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

# Draw text labels near the points, and highlight based on selection
text = line.mark_text(align='left', dx=5, dy=-5).encode(
    text=alt.condition(nearest, 'Mortgage Affordability:Q', alt.value(' '))
)

# Draw a rule at the location of the selection
rules = alt.Chart(ma_long).mark_rule(color='gray').encode(
    x='Time:T',
).transform_filter(
    nearest
)

# Put the five layers into a chart and bind the data
alt.layer(
    line, selectors, points, rules, text
).properties(
    width=600, height=500
)

# %% [markdown]
# ## Renter Affordability Historical Data with Interaction

# %%
# Load in data
ra_long = pd.read_csv('./data_for_plot/ra_ts_data.csv')

# %%
# Create a selection that chooses the nearest point & selects based on x-value
nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['Time'], empty='none')

# The basic line
line = alt.Chart(ra_long).mark_line(interpolate='basis').encode(
    x='Time:T',
    y='Renter Affordability:Q',
    color='Area:N'
)

# Transparent selectors across the chart. This is what tells us
# the x-value of the cursor
selectors = alt.Chart(ra_long).mark_point().encode(
    x='Time:T',
    opacity=alt.value(0),
).add_selection(
    nearest
)

# Draw points on the line, and highlight based on selection
points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

# Draw text labels near the points, and highlight based on selection
text = line.mark_text(align='left', dx=5, dy=-5).encode(
    text=alt.condition(nearest, 'Renter Affordability:Q', alt.value(' '))
)

# Draw a rule at the location of the selection
rules = alt.Chart(ra_long).mark_rule(color='gray').encode(
    x='Time:T',
).transform_filter(
    nearest
)

# Put the five layers into a chart and bind the data
alt.layer(
    line, selectors, points, rules, text
).properties(
    width=600, height=500
)
